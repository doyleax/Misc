# %%
import numpy as np
import pandas as pd

url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/fandango/fandango_score_comparison.csv'
movies = pd.read_csv(url)

# %%
print movies
# Out:
#                                                FILM  RottenTomatoes  \
# 0                    Avengers: Age of Ultron (2015)              74
# 1                                 Cinderella (2015)              85
# 2                                    Ant-Man (2015)              80
# 3                            Do You Believe? (2015)              18
# 4                     Hot Tub Time Machine 2 (2015)              14
# 5                          The Water Diviner (2015)              63
# 6                             Irrational Man (2015)              42
# 7                                   Top Five (2014)              86
# 8                      Shaun the Sheep Movie (2015)              99
# 9                               Love & Mercy (2015)              89
# 10                Far From The Madding Crowd (2015)              84
# 11                                 Black Sea (2015)              82
# 12                                 Leviathan (2014)              99
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(movies.Fandango_Stars)
# Out:
# (array([ 12.,   0.,  27.,   0.,   0.,  41.,   0.,  55.,   0.,  11.]),
#  array([ 3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,  4.4,  4.6,  4.8,  5. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(movies.Metacritic_norm_round)
# Out:
# (array([  1.,   2.,  20.,  14.,   0.,  22.,  27.,  20.,  25.,  15.]),
#  array([ 0.5,  0.9,  1.3,  1.7,  2.1,  2.5,  2.9,  3.3,  3.7,  4.1,  4.5]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# The top histogram for Fandango_Stars shows that movies are only receiving 3, 3.5, 4, 4.5, and 5 stars.
#
# Metacritic, however, rates movies on a scale of 0.5-4.5, with the majority receiving around 2.5-4.5 stars.

# %%
movies.Metacritic_norm_round.value_counts()
# Out:
# 3.0    27
# 4.0    25
# 2.5    22
# 1.5    20
# 3.5    20
# 4.5    15
# 2.0    14
# 1.0     2
# 0.5     1
# Name: Metacritic_norm_round, dtype: int64
